# %%
import pandas as pd

from rec_gov_automate.availability import get_river_permit_availability_by_month

# %%
permit_id = 234623  # middle fork
month = 10
day = 19

# %%
avail_df = get_river_permit_availability_by_month(permit_id, month)

avail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 5 to 30
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             26 non-null     datetime64[ns, UTC]
#  1   total            26 non-null     object
#  2   remaining        26 non-null     object
#  3   show_walkup      26 non-null     object
#  4   is_secret_quota  26 non-null     object
# dtypes: datetime64[ns, UTC](1), object(4)
# memory usage: 1.2+ KB

# %%
avail_df = avail_df.loc[
    (avail_df['date'].dt.day == day)
    & (avail_df['remaining'] > 0)
]

avail = avail_df.shape[0] == 1

avail
# Out:
# True
