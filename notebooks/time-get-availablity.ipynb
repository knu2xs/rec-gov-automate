# %%
from rec_gov_automate import get_fourrivers_availability

# %%
# %%timeit

get_fourrivers_availability(permit_season=True, only_available=True)
# Out:
# 937 ms ± 7.33 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
