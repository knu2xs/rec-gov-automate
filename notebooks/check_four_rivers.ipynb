# %%
from datetime import date, datetime
from pathlib import Path

import pandas as pd

from rec_gov_automate import FourRivers, get_fourrivers_availability
from rec_gov_automate.utils.notification import send_pushover

# %%
search_data = Path.cwd().parent / 'data' / 'external' / 'four_rivers_search.csv'
search_data = Path.cwd().parent / 'testing' / 'four_rivers_search_test.csv'

assert search_data.exists()

search_df = pd.read_csv(search_data)

search_df
# Out:
#    search_group    river_key  month  day  putin_id  takeout_id  \
# 0             0  main_salmon     12   25       NaN         NaN
# 1             0  main_salmon     12   26       NaN         NaN
# 2             0  main_salmon      7    4       NaN         NaN
#
#    permit_pickup_id  days  checkout  recgov_user  recgov_pass
# 0               NaN   NaN       NaN          NaN          NaN
# 1               NaN   NaN       NaN          NaN          NaN
# 2               NaN   NaN       NaN          NaN          NaN

# %%
avail_df = get_fourrivers_availability(search_df=search_df)

avail_df
# Out:
#    search_group    river_key  putin_id  takeout_id  permit_pickup_id  days  \
# 0             0  main_salmon       NaN         NaN               NaN   NaN
# 1             0  main_salmon       NaN         NaN               NaN   NaN
#
#    checkout  recgov_user  recgov_pass                      date total  \
# 0       NaN          NaN          NaN 2025-12-25 00:00:00+00:00    99
# 1       NaN          NaN          NaN 2025-12-26 00:00:00+00:00    99
#
#   remaining
# 0        99
# 1        99

# %%
avail_df = get_fourrivers_availability(permit_season=True, only_available=True)

avail_df
# Out:
# Empty DataFrame
# Columns: [river, date, total, remaining, retrive_timestamp, days_to_launch]
# Index: []

# %%
for avail_row in avail_df.itertuples():
    break

# %%
FourRivers._get_river(avail_row.river_key)
# Out:
# FourRivers (234622)

# %%
notify_str = "Four Rivers cancellations are available!\n\n"

for _, river_key, launch_dt, permit_cnt in avail_df[['river_key', 'date', 'remaining']].itertuples():

    # format the name of the river
    river_name = river_key.replace('_', ' ').title()

    # format the date
    dt_str = launch_dt.strftime('%a %d%b')

    # assemble the string
    avail_str = f'{river_name}: {dt_str} - {permit_cnt} permits\n'

    # add the string
    notify_str = notify_str + avail_str

    

print(notify_str)
# Out:
# Four Rivers cancellations are available!
#
# Main Salmon: Thu 25Dec - 99 permits
# Main Salmon: Fri 26Dec - 99 permits

# %%
send_pushover(notify_str)
# Out:
# <Response [200]>
