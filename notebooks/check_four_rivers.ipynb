# %%
from rec_gov_automate import FourRivers

# %%
river = FourRivers.get_main_salmon()

river
# Out:
# FourRivers (234622)

# %%
avail_df = river.get_permit_season_availability()

avail_df
# Out:
#           river                      date total remaining  \
# 0   main_salmon 2025-05-28 00:00:00+00:00    99        99
# 1   main_salmon 2025-05-29 00:00:00+00:00    99        99
# 2   main_salmon 2025-05-30 00:00:00+00:00    99        99
# 3   main_salmon 2025-05-31 00:00:00+00:00    99        99
# 4   main_salmon 2025-06-01 00:00:00+00:00    99        99
# ..          ...                       ...   ...       ...
# 94  main_salmon 2025-08-30 00:00:00+00:00     8         0
# 95  main_salmon 2025-08-31 00:00:00+00:00     8         0
# 96  main_salmon 2025-09-01 00:00:00+00:00     8         0
# 97  main_salmon 2025-09-02 00:00:00+00:00     8         0
# 98  main_salmon 2025-09-03 00:00:00+00:00     8         0
#
#                   retrive_timestamp  days_to_launch
# 0  2025-02-11 19:02:34.537575+00:00             105
# 1  2025-02-11 19:02:34.537575+00:00             106
# 2  2025-02-11 19:02:34.537575+00:00             107
# 3  2025-02-11 19:02:34.537575+00:00             108
# ...

# %%
avail_df[avail_df['remaining'] > 0]
# Out:
#           river                      date total remaining  \
# 0   main_salmon 2025-05-28 00:00:00+00:00    99        99
# 1   main_salmon 2025-05-29 00:00:00+00:00    99        99
# 2   main_salmon 2025-05-30 00:00:00+00:00    99        99
# 3   main_salmon 2025-05-31 00:00:00+00:00    99        99
# 4   main_salmon 2025-06-01 00:00:00+00:00    99        99
# 5   main_salmon 2025-06-02 00:00:00+00:00    99        99
# 6   main_salmon 2025-06-03 00:00:00+00:00    99        99
# 7   main_salmon 2025-06-04 00:00:00+00:00    99        99
# 8   main_salmon 2025-06-05 00:00:00+00:00    99        98
# 9   main_salmon 2025-06-06 00:00:00+00:00    99        99
# 10  main_salmon 2025-06-07 00:00:00+00:00    99        97
# 11  main_salmon 2025-06-08 00:00:00+00:00    99        98
# 12  main_salmon 2025-06-09 00:00:00+00:00    99        96
# 13  main_salmon 2025-06-10 00:00:00+00:00    99        99
# 14  main_salmon 2025-06-11 00:00:00+00:00    99        97
# ...

# %%
river.check_availability(day=28, month=5)
# Out:
# True
